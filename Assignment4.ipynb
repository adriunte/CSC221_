# %% [markdown]
# <a href="https://colab.research.google.com/github/adriunte/CSC221_acast051/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#3-1
names = ["Hemsel", "Nat", "Richard", "Deion", "Kaela", "Kimberly"]
print(names[0])
print(names[1])
print(names[2])
print(names[3])
print(names[4])
print(names[5])

#3-2
greetings = f"\nOh why hello to my good ol buddy {names[0]}."
print(greetings)
greetings = f"Oh why hello to my good ol buddy {names[1]}."
print(greetings)
greetings = f"Oh why hello to my good ol buddy {names[2]}."
print(greetings)
greetings = f"Oh why hello to my good ol buddy {names[3]}."
print(greetings)
greetings = f"Oh why hello to my good ol buddy {names[4]}."
print(greetings)
greetings = f"Oh why hello to my good ol buddy {names[5]}.\n"
print(greetings)

#3-3
transport = ["Buggati", "motor", "plane"]
ride = f"Man I sure do love riding my {transport[0]}."
print(ride)
ride = f"Man I sure do love riding my {transport[1]}."
print(ride)
ride = f"Man I sure do love riding my {transport[2]}."
print(ride)

# %%
#3-4
invites = ["Robert Kiyosaki", "Fermin Castillo", "Andrew Tate"]
thanks = f'Mr. {invites[0]} I would love to invite you to my dinner.'
print(thanks)
thanks = f'Mr. {invites[1]} I would love to invite you to my dinner.'
print(thanks)
thanks = f'Mr. {invites[2]} I would love to invite you to my dinner.\n'
print(thanks)

#3-5
popped_person = invites.pop()
print(f"I regret to inform you all but {popped_person} won't be able to make it tonight.")
new_person = invites.append('Tristian Tate')
thanks = f'Mr. {invites[0]} I would love to invite you to my dinner.'
print(thanks)
thanks = f'Mr. {invites[1]} I would love to invite you to my dinner.'
print(thanks)
thanks = f'Mr. {invites[2]} I would love to invite you to my dinner.\n'
print(thanks)

#3-6
print("Lucky me, an extra table and more coding to do. We will have three more guess.")
new = invites.insert(0, "Don Roberto")
new = invites.insert(2, "Dona Zoila")
new = invites.append("Adrian Castillo")
thanks = f'Mr. {invites[0]} I would love to invite you to my dinner.'
print(thanks)
thanks = f'Mr. {invites[1]} I would love to invite you to my dinner.'
print(thanks)
thanks = f'Mr. {invites[2]} I would love to invite you to my dinner.'
print(thanks)
thanks = f'Mr. {invites[3]} I would love to invite you to my dinner.'
print(thanks)
thanks = f'Mr. {invites[4]} I would love to invite you to my dinner.'
print(thanks)
thanks = f'Mr. {invites[5]} I would love to invite you to my dinner.\n'
print(thanks)

#3-7
print("Can only invite two of you guys, four of you will have to go.")
guess = 6
yay = True

while guess != 2:
  popped_you = invites.pop()
  print(f'Sorry {popped_you} but we no longer have space for you.')
  guess = guess - 1
thanks = f'\nMr. {invites[0]} I would love to invite you to my dinner still.'
print(thanks)
thanks = f'Mr. {invites[1]} I would love to invite you to my dinner still.'
print(thanks)
del invites[0]
del invites[0]
print(invites)

#3-8
loca = ['France', 'Dominican Republic', 'Colombia', 'Mexico', 'Brazil']
print(loca)
print(sorted(loca))
print(loca)
print(sorted(loca, reverse=True))
print(loca)
loca.reverse()
print(loca)
loca.reverse()
print(loca)
loca.sort()
print(loca)
loca.sort(reverse=True)
print(loca)

#3-9
print(f"\nWe have {len(invites)} people coming tonight.")

#3-10
streets = ['Dyckman', 'Thayer', 'Sickles', 'Broadway', 'Sherman']
print(f'\n{streets[0]}')
print(f'My favorite street is {streets[0]}')
print(streets.pop())
streets.append('Post')
streets.insert(3, 'Academy')
sorted(streets)
sorted(streets, reverse=True)
streets.reverse()
streets.sort()
streets.sort(reverse=True)
print(streets)
# Out:
# Mr. Robert Kiyosaki I would love to invite you to my dinner.
# Mr. Fermin Castillo I would love to invite you to my dinner.
# Mr. Andrew Tate I would love to invite you to my dinner.
#
# I regret to inform you all but Andrew Tate won't be able to make it tonight.
# Mr. Robert Kiyosaki I would love to invite you to my dinner.
# Mr. Fermin Castillo I would love to invite you to my dinner.
# Mr. Tristian Tate I would love to invite you to my dinner.
#
# Lucky me, an extra table and more coding to do. We will have three more guess.
# Mr. Don Roberto I would love to invite you to my dinner.
# Mr. Robert Kiyosaki I would love to invite you to my dinner.
# Mr. Dona Zoila I would love to invite you to my dinner.
# Mr. Fermin Castillo I would love to invite you to my dinner.
# Mr. Tristian Tate I would love to invite you to my dinner.
# Mr. Adrian Castillo I would love to invite you to my dinner.
#
# Can only invite two of you guys, four of you will have to go.
# ...
