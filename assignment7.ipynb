# %% [markdown]
# <a href="https://colab.research.google.com/github/adriunte/CSC221_acast051/blob/main/assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#6-1
alex = {'first_name': "alex", 'last_name': 'castillo', 'age': 21, 'city': 'new york'}
print(alex['first_name'])
print(alex['last_name'])
print(alex['age'])
print(alex['city'], '\n')

#6-2
fav_number = {'adrian': 8, 'alex': 7, 'kimberly': 7, 'dad': 16, 'mom': 9}
print(f"Adrian favorite number is {fav_number['adrian']}")
print(f"Alex favorite number is {fav_number['alex']}")
print(f"Kimberly favorite number is {fav_number['kimberly']}")
print(f"Dad favorite number is {fav_number['dad']}")
print(f"Mom favorite number is {fav_number['mom']}\n")

#6-3
words = {'keys': "name of a value", 'key-value': "a name and its value in a dict",
         'element': "a item in a list", 'list': "something containing elements",
         'tuple': "similar to list but can't be changed",}

for key, value in words.items():
    sentence = "'{}'\n Meanings: '{}'.".format(key, value)
    print(sentence)

#6-4
# Alright had a clean code lol
words = {'keys': "name of a value", 'key-value': "a name and its value in a dict",
         'element': "a item in a list", 'list': "something containing elements",
         'tuple': "similar to list but can't be changed",
         'Syntax': 'Syntax refers to the rules and structure of the Python language',
         'Variable': 'A variable is a named storage location in memory that holds a value',
         'Data Type': 'A data type defines the kind of data that a variable can hold',
         'String': 'A string is a sequence of characters enclosed in single or double quotes',
         'Float': 'A float (floating-point number) is a number that has a decimal point or an exponent',}
print('\n')
for key, value in words.items():
    sentence = "'{}'\n Meanings: '{}'.".format(key, value)
    print(sentence)
print('\n')

#6-5
river = { 'nile':'egypt', 'hudson':'USA', 'colorado river':'USA'}
for rivers, country in river.items():
  print(f"The {rivers} runs through the country of {country}.")

for i in river.keys():
  print(i)

for i in river.values():
  print(i)
print('\n')

#6-6
fav_languages = {
    'jen':'python',
    'sarah':'c',
    'edward':'rust',
    'phil':'python',
}

stake = ['deion', 'david', 'jen', 'sarah']

for i in stake:
  if i in fav_languages:
    print(f'{i}, thank you for responding.')
  else:
    print(f'{i} you should take the poll.')

#6-7
alex = {'first_name': "alex", 'last_name': 'castillo', 'age': 21, 'city': 'new york'}
hemsel = {'first_name': "hemsel", 'last_name': 'aberu', 'age': 21, 'city': 'san francisco'}
kimberly = {'first_name': "kimberly", 'last_name': 'motieram', 'age': 20, 'city': 'the bronx'}
peoples = [alex, hemsel, kimberly]
print('\n')
for peeps in peoples:
  print(f'Info on {(peeps["first_name"]).title()}:')
  name_is = f'{peeps["first_name"]} {peeps["last_name"]}'
  age_is = f'{peeps["age"]}'
  hometown = f'{peeps["city"]}\n'
  print(f'\tname: {name_is.title()}')
  print(f'\tage: {age_is}')
  print(f'\tcity: {hometown.title()}')

#6-8
pet_1 = {'type':'lizard', 'owner':'Kim'}
pet_2 = {'type':'dog', 'owner':'Jorge'}
pet_3 = {'type':'sister', 'owner':'Hemsel'}
pet_4 = {'type':'cat', 'owner':'Kaela'}
pets = [pet_1, pet_2, pet_3, pet_4]
for pet in pets:
  print(f"{pet['owner']}'s pet is a {pet['type']}.")

#6-9
favorite_places = {
    'Alice': ['Paris', 'London'],
    'Bob': ['New York'],
    'Charlie': ['Sydney', 'Tokyo', 'Berlin']
}
print()

for person, places in favorite_places.items():
    print(f"{person}'s favorite places are:")
    for place in places:
        print(f"- {place}")
    print()

#6-10
adri = [8, 2, 5]
ale = [7, 2, 8]
kimber = [7, 16]
da = [16, 4, 59]
ma = [9, 0, 67]

fav_number = {'adrian': adri, 'alex': ale, 'kimberly': kimber, 'dad': da, 'mom': ma}
for person, num in fav_number.items():
  print(f"{person.title()} favorite numbers are:")
  for i in num:
    print(i)

#6-11
cities = {
    'New York': {
        'country': 'USA',
        'population': 8398748,
        'fact': 'New York City is known as "The Big Apple."'
    },
    'Paris': {
        'country': 'France',
        'population': 2140526,
        'fact': 'Paris is often called the "City of Love."'
    },
    'Tokyo': {
        'country': 'Japan',
        'population': 13929286,
        'fact': 'Tokyo is the largest city in Japan and one of the most populous metropolitan areas in the world.'
    }
}

for city, info in cities.items():
    print(f"City: {city}")
    print(f"Country: {info['country']}")
    print(f"Population: {info['population']}")
    print(f"Fact: {info['fact']}")
    print()

#6-12
cities = {
    'New York': {
        'country': 'USA',
        'population': 8398748,
        'fact': 'New York City is known as "The Big Apple."',
        'famous_landmarks': ['Statue of Liberty', 'Central Park', 'Times Square'],
        'language': 'English',
    },
    'Paris': {
        'country': 'France',
        'population': 2140526,
        'fact': 'Paris is often called the "City of Love."',
        'famous_landmarks': ['Eiffel Tower', 'Louvre Museum', 'Notre-Dame Cathedral'],
        'language': 'French',
    },
    'Tokyo': {
        'country': 'Japan',
        'population': 13929286,
        'fact': 'Tokyo is the largest city in Japan and one of the most populous metropolitan areas in the world.',
        'famous_landmarks': ['Tokyo Skytree', 'Shibuya Crossing', 'Imperial Palace'],
        'language': 'Japanese',
    }
}

for city, info in cities.items():
    print(f"City: {city}")
    print(f"Country: {info['country']}")
    print(f"Population: {info['population']:,}")
    print(f"Language: {info['language']}")
    print("Famous Landmarks:")
    for landmark in info['famous_landmarks']:
        print(f"- {landmark}")
    print(f"Fun Fact: {info['fact']}")
    print()
# Out:
# alex
# castillo
# 21
# new york
#
# Adrian favorite number is 8
# Alex favorite number is 7
# Kimberly favorite number is 7
# Dad favorite number is 16
# Mom favorite number is 9
#
# 'keys'
#  Meanings: 'name of a value'.
# 'key-value'
#  Meanings: 'a name and its value in a dict'.
# 'element'
#  Meanings: 'a item in a list'.
# 'list'
#  Meanings: 'something containing elements'.
# 'tuple'
#  Meanings: 'similar to list but can't be changed'.
#
#
# 'keys'
#  Meanings: 'name of a value'.
# 'key-value'
#  Meanings: 'a name and its value in a dict'.
# 'element'
#  Meanings: 'a item in a list'.
# 'list'
#  Meanings: 'something containing elements'.
# 'tuple'
#  Meanings: 'similar to list but can't be changed'.
# 'Syntax'
#  Meanings: 'Syntax refers to the rules and structure of the Python language'.
# 'Variable'
#  Meanings: 'A variable is a named storage location in memory that holds a value'.
# 'Data Type'
#  Meanings: 'A data type defines the kind of data that a variable can hold'.
# ...
