# %% [markdown]
# <a href="https://colab.research.google.com/github/adriunte/CSC221_acast051/blob/main/Assignment11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Dog:
    """A simple attempt to model a dog."""

    def __init__(self, name, age):
        """Initialize name and age attributes."""
        self.name = name
        self.age = age

    def sit(self):
        print(f"{self.name} is now sitting.")
    def rollover(self):
        print(f"{self.name} rolled over!")

my_dog = Dog('Willie', 6)
print(f"My dog's name is {my_dog.name}.")
print(f"My dog is {my_dog.age} years old.")
my_dog.sit()
my_dog.rollover()

#9-1
print('\n')
class Restaurant:
    """Initializing restaurant details"""

    def __init__(self, restaurant_name, cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type

    def describe_restaurant(self):
        print(f"{self.restaurant_name} is a {self.cuisine_type} type of restaurant.")

    def open_restaurant(self):
        print("The restaurant is now open!")

restaurant = Restaurant('Borgos', 'Dominican')
restaurant.describe_restaurant()
restaurant.open_restaurant()

#9-2
print("\n")
popeyes = Restaurant('Popeyes', 'Fried Chicken')
popeyes.describe_restaurant()

dyckman = Restaurant('Dyckman Express', 'Dominican')
dyckman.describe_restaurant()

chinese = Restaurant('Pica Pollo', 'Chinese')
chinese.describe_restaurant()

#9-3
print("\n")
class User:
    def __init__(self, first_name, last_name):
        self.first_name = first_name
        self.last_name = last_name

    def describe_user(self):
        print(f"This user's name is {self.first_name.title()} {self.last_name.title()}.")


    def greet_user(self):
        print(f"Hello {self.first_name.title()} {self.last_name.title()}!")


adrian = User('adrian', 'castillo')
adrian.describe_user()
adrian.greet_user()

kimberly = User('kimberly', 'motieram')
kimberly.describe_user()
kimberly.greet_user()

kaela = User('kaela', 'de leon')
kaela.describe_user()
kaela.greet_user()

#car class
print('\n')

class Car:
  """a simple attempt to represent a car."""

  def __init__(self, make, model, year):
    """Initialize attributes to describe a car."""
    self.make = make
    self.model = model
    self.year = year
    self.odometer_reading = 0

  def get_descriptive_name(self):
    """Return a neatly formatted descriptive name."""
    long_name = f"{self.year} {self.make} {self.model}"
    return long_name.title()

  def read_odometer(self):
    print(f"This car has {self.odometer_reading} miles on it.")

  def update_odometer(self, mileage):
    if mileage >= self.odometer_reading:
      self.odometer_reading = mileage
    else:
      print("You can't roll back an odometer!")

  def increment_odometer(self, miles):
    self.odometer_reading += miles

my_new_car = Car('audi', 'a4', 2024)
print(my_new_car.get_descriptive_name())
my_new_car.read_odometer()

my_new_car.odometer_reading = 23
my_new_car.read_odometer()

my_new_car.update_odometer(20)
my_new_car.read_odometer()

print('\n')

my_used_car = Car('subaru', 'outback', 2019)
print(my_used_car.get_descriptive_name())

my_used_car.update_odometer(23500)
my_used_car.read_odometer()

my_used_car.increment_odometer(100)
my_used_car.read_odometer()

print('\n')

class Battery:
  """A simple attempt to model a battery for an electric car."""

  def __init__(self, battery_size=40):
    self.battery_size = battery_size

  def describe_battery(self):
    """Print a statement describing the battery size."""
    print(f"This car has a {self.battery_size}-kWh battery.")

  def get_range(self):
    """Print a statement about the range this battery provides."""

class ElectricCar(Car):
  def __init__(self, make, model, year):
    super().__init__(make, model, year)
    self.battery = Battery()

  def describe_battery(self):
    """Print a statement describing the battery size."""
    print(f"This car has a {self.battery_size}-kWh battery.")

my_leaf = ElectricCar('nissan', 'leaf', 2024)
print(my_leaf.get_descriptive_name())
my_leaf.battery.describe_battery()

class IceCreamStand(Restaurant):
  def __init__(self, cuisine_type, flavors=None):
    super().__init__(cuisine_type, flavors)
    self.flavors = flavors

  def describe_flavors(self):
    print("We have these flavors in store:")
    for i in self.flavors:
      print(f"- {i}")

flavor = ['vanilla', 'chocolate']

icey = IceCreamStand('icecream shop', flavors=flavor)
icey.describe_flavors()

print('\n')

class Admin(User):
  def __init__(self, first_name, last_name, privileges=None):
    super().__init__(first_name, last_name)
    if privileges is None:
      self.privileges = []
    else:
      self.privileges = privileges

  def show_privileges(self):
    print(f"These are Admin {self.first_name} {self.last_name}'s privileges:")
    for privilege in self.privileges:
      print(f'- {privilege}')

p = ['can add post', 'can delete post', 'can ban user']
adminie = Admin('Adrian', 'Castillo', privileges=p)
adminie.show_privileges()
# Out:
# My dog's name is Willie.
# My dog is 6 years old.
# Willie is now sitting.
# Willie rolled over!
#
#
# Borgos is a Dominican type of restaurant.
# The restaurant is now open!
#
#
# Popeyes is a Fried Chicken type of restaurant.
# Dyckman Express is a Dominican type of restaurant.
# Pica Pollo is a Chinese type of restaurant.
#
#
# This user's name is Adrian Castillo.
# Hello Adrian Castillo!
# This user's name is Kimberly Motieram.
# Hello Kimberly Motieram!
# This user's name is Kaela De Leon.
# Hello Kaela De Leon!
#
#
# 2024 Audi A4
# This car has 0 miles on it.
# This car has 23 miles on it.
# You can't roll back an odometer!
# This car has 23 miles on it.
#
#
# 2019 Subaru Outback
# This car has 23500 miles on it.
# This car has 23600 miles on it.
#
#
# 2024 Nissan Leaf
# This car has a 40-kWh battery.
# We have these flavors in store:
# - vanilla
# - chocolate
#
#
# These are Admin Adrian Castillo's privileges:
# - can add post
# - can delete post
# - can ban user
